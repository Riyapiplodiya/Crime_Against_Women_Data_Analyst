# %%
import pandas as pd
import matplotlib.pyplot as plt
file_path= "C:\\Users\\pc\\.ipynb_checkpoints\\dataforproject.csv"
df=pd.read_csv(file_path)
df.head(2)
# Out:
#             State/UT  Trafficking  Murder with Rape/Gang Rape  Dowry Deaths  \
# 0     Andhra Pradesh          107                           8           100
# 1  Arunachal pradesh            1                           0             0
#
#    Abetment to Suicide of Women   Miscarriage  Acid Attack  \
# 0                            358            4            3
# 1                              0            0            0
#
#    Attempt to Acid Attack  Cruelty by Husband/relatives  Kidnapping/Abduction  \
# 0                       3                         11964                   592
# 1                       0                            74                    48
#
#    ...  Rape  Attempt to Commit Rape  Assault to Outrage her Modesty  \
# 0  ...   621                     180                            5884
# 1  ...    74                       3                              67
#
#    Insult to the Modesty of Women  Assault due to Dowry  Domestic violence  \
# ...

# %%
df.isnull().sum()
# Out:
# State/UT                                0
# Trafficking                             0
# Murder with Rape/Gang Rape              0
# Dowry Deaths                            0
# Abetment to Suicide of Women            0
# Miscarriage                             0
# Acid Attack                             0
# Attempt to Acid Attack                  0
# Cruelty by Husband/relatives            0
# Kidnapping/Abduction                    0
# Selling of Minor Girls                  0
# Buying of Minor Girls                   0
# Rape                                    0
# Attempt to Commit Rape                  0
# Assault to Outrage her Modesty          0
# Insult to the Modesty of Women          0
# Assault due to Dowry                    0
# Domestic violence                       0
# Cyber Crimes committed against women    0
# Sexual Violence towards girl child      0
# Indecent Representation of Women        0
# Total Crime against Women (IPC &SLL)    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 22 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   State/UT                              35 non-null     object
#  1   Trafficking                           35 non-null     int64
#  2   Murder with Rape/Gang Rape            35 non-null     int64
#  3   Dowry Deaths                          35 non-null     int64
#  4   Abetment to Suicide of Women          35 non-null     int64
#  5   Miscarriage                           35 non-null     int64
#  6   Acid Attack                           35 non-null     int64
#  7   Attempt to Acid Attack                35 non-null     int64
#  8   Cruelty by Husband/relatives          35 non-null     int64
#  9   Kidnapping/Abduction                  35 non-null     int64
#  10  Selling of Minor Girls                35 non-null     int64
# ...

# %%
df.shape
# Out:
# (35, 22)

# %%
df.describe()
# Out:
#        Trafficking  Murder with Rape/Gang Rape  Dowry Deaths  \
# count    35.000000                   35.000000     35.000000
# mean     49.342857                    6.771429    184.285714
# std      71.617835                   12.518423    400.534318
# min       0.000000                    0.000000      0.000000
# 25%       1.000000                    0.000000      1.000000
# 50%      16.000000                    2.000000     29.000000
# 75%      68.500000                    7.500000    177.500000
# max     283.000000                   62.000000   2138.000000
#
#        Abetment to Suicide of Women   Miscarriage  Acid Attack  \
# count                      35.000000    35.000000    35.000000
# mean                      142.685714     6.742857     3.485714
# std                       200.691565    17.076545     6.404830
# min                         0.000000     0.000000     0.000000
# 25%                         3.500000     0.000000     0.000000
# ...

# %% [markdown]
# df.duplicated().sum()

# %%
x = df['Trafficking']  # This will be plotted on the X-axis
y = df['State/UT']  # This will be plotted on the Y-axis
# Step 3: Plot the data
plt.figure(figsize=(10,10))
plt.plot(x, y,marker='o', color='blue')

# Adding labels and title
plt.xlabel('Trafficking')
plt.ylabel('State/UT')
plt.title('Trafficking Count Over the States')

# Display the graph
plt.show()

# %%
x = df['Dowry Deaths']  # This will be plotted on the X-axis
y = df['State/UT']  # This will be plotted on the Y-axis
# Step 3: Plot the data
plt.figure(figsize=(10,10))
plt.plot(x, y,marker='o', color='red')

# Adding labels and title
plt.xlabel('Dowry Deaths')
plt.ylabel('State/UT')
plt.title('Dowry Deaths Count Over the States')

# Display the graph
plt.show()

# %%
x = df['Rape']  # This will be plotted on the X-axis
y = df['State/UT']  # This will be plotted on the Y-axis
# Step 3: Plot the data
plt.figure(figsize=(20,30))
plt.pie(x,labels=y,autopct='%1.1f%%')

# Adding labels and title
plt.xlabel('Rape')
plt.ylabel('State/UT')
plt.title('Rape, Count Over the States')

# Display the graph
plt.show()

# %%
x = df['State/UT']  # This will be plotted on the X-axis
y = df['Acid Attack']  # This will be plotted on the Y-axis
# Step 3: Plot the data
plt.figure(figsize=(22,10))
plt.barh(x,y,color='green')

# Adding labels and title
plt.xlabel('State/UT')
plt.ylabel('Acid Attack')
plt.title('Acid Attack Over the States')

# Display the graph
plt.show()

# %%
x = df['State/UT']  # This will be plotted on the X-axis
y = df['Domestic violence']  # This will be plotted on the Y-axis
# Step 3: Plot the data
plt.figure(figsize=(20,10))
plt.barh(x,y,color='pink')

# Adding labels and title
plt.xlabel('State/UT')
plt.ylabel('Domestic violence')
plt.title('Domestic violence Over the States')

# Display the graph
plt.show()

# %%
x = df['Kidnapping/Abduction']  # This will be plotted on the X-axis
y = df['State/UT']  # This will be plotted on the Y-axis
# Step 3: Plot the data
plt.figure(figsize=(30,10))
plt.scatter(x,y,c='purple',marker='o')
# Adding labels and title
plt.xlabel('Kidnapping/Abduction')
plt.ylabel('State/UT')
plt.title('Kidnapping/Abduction Over the States')

# Display the graph
plt.show()

# %%
average1 = df['Trafficking'].mean()

print("Average of trafficking in india:", average1)
# Out:
# Average of trafficking in india: 49.34285714285714

# %%
average2 = df['Dowry Deaths'].mean()

print("Average of Dowry Deaths in india:", average2)
# Out:
# Average of Dowry Deaths in india: 184.28571428571428

# %%
average3 = df['Rape'].mean()

print("Average of Rape in india:", average3)
# Out:
# Average of Rape in india: 900.5142857142857

# %%
average4 = df['Acid Attack'].mean()

print("Average of Acid Attack in india:", average4)
# Out:
# Average of Acid Attack in india: 3.4857142857142858

# %%
average5 = df['Domestic violence'].mean()

print("Average of Domestic violence in india:", average5)
# Out:
# Average of Domestic violence in india: 13.371428571428572

# %%
average6 = df['Kidnapping/Abduction'].mean()

print("Average of Kidnapping/Abduction in india:", average6)
# Out:
# Average of Kidnapping/Abduction in india: 2437.3142857142857
